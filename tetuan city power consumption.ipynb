# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Admin/Desktop/40 projects/Tetuan City power consumption.csv')
df
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# ...

# %%
fig, ax = plt.subplots(figsize=(25,10))         # Sample figsize in inches

sns.heatmap(df.corr(), annot=True, cmap="RdBu", ax=ax)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DateTime                   52416 non-null  object
#  1   Temperature                52416 non-null  float64
#  2   Humidity                   52416 non-null  float64
#  3   Wind Speed                 52416 non-null  float64
#  4   general diffuse flows      52416 non-null  float64
#  5   diffuse flows              52416 non-null  float64
#  6   Zone 1 Power Consumption   52416 non-null  float64
#  7   Zone 2  Power Consumption  52416 non-null  float64
#  8   Zone 3  Power Consumption  52416 non-null  float64
#  9   Sum                        52416 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 4.0+ MB

# %%
df.drop(['Zone 1 Power Consumption'], axis=1, inplace=True)
df.drop(['Zone 2  Power Consumption'], axis=1, inplace=True)
df.drop(['Zone 3  Power Consumption'], axis=1, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(25,10))         # Sample figsize in inches

sns.heatmap(df.corr(), annot=True, cmap="RdBu", ax=ax)
# Out:
# <Axes: >

# %%
sns.pairplot(df, corner = True)
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python310\\site-packages\\xxhash\\_xxhash.cp310-win_amd64.pyd'
# Check the permissions.
# ...
#   Using cached pycaret-3.0.0-py3-none-any.whl (481 kB)
# ...
#   Using cached llvmlite-0.39.1-cp310-cp310-win_amd64.whl (23.2 MB)
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# ...
#   Using cached numpy-1.24.2-cp310-cp310-win_amd64.whl (14.8 MB)
# ...
#   Using cached pyod-1.0.9-py3-none-any.whl
# ...
#   Using cached xxhash-3.2.0-cp310-cp310-win_amd64.whl (30 kB)
# ...
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# ...
#   Using cached ipython-8.12.0-py3-none-any.whl (796 kB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
# ...
#   Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
# ...
#   Using cached scikit_learn-1.2.2-cp310-cp310-win_amd64.whl (8.3 MB)
# ...

# %%
#!pip install  pycaret --ignore-installed llvmlite

# %%
#!pip install numpy==1.20
# Out:
# ^C

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

# %%
data_train = df.sample(frac=0.8, random_state=1360)
data_test  = df.drop(data_train.index)

data_train.reset_index(drop=True, inplace=True)
data_test.reset_index(drop=True, inplace=True)

print ('Data for Modeling : ' + str(data_train.shape))
print ('Data for Prediction : ' + str(data_test.shape))
# Out:
# Data for Modeling : (41933, 7)
# Data for Prediction : (10483, 7)

# %%
from pycaret.regression import *
s = setup(data=data_train, target='Sum', fold_shuffle=True, session_id=123, imputation_type='iterative')
# Out:
# <style type="text/css">
# #T_89add_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_89add">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89add_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_89add_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89add_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89add_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_89add_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_89add_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89add_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_89add_row1_col1" class="data row1 col1" >Sum</td>
#     </tr>
#     <tr>
#       <th id="T_89add_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                17:38:45
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .   Extra Trees Regressor
# <style type="text/css">
# #T_6093d th {
#   text-align: left;
# }
# ...
